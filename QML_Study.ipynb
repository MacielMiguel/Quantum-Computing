# %%
pip install Aer
# Out:
# Collecting Aer
#   Using cached aer-0.3.0-py3-none-any.whl.metadata (685 bytes)
# Requirement already satisfied: click<8.0.0,>=7.1.2 in ./.qml/lib/python3.12/site-packages (from Aer) (7.1.2)
# Using cached aer-0.3.0-py3-none-any.whl (2.7 kB)
# Installing collected packages: Aer
# Successfully installed Aer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from qiskit import * 
from qiskit.visualization import *
from math import pi

# %%
plot_bloch_vector([0,1,0], title="Bloch Sphere")

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.y(0)
qc.z(0)
qc.draw()
# Out:
#    ┌───┐┌───┐┌───┐
# q: ┤ X ├┤ Y ├┤ Z ├
#    └───┘└───┘└───┘

# %%
def x_measurement(qc, qubit, cbit):
    qc.h(qubit)
    qc.measure(qubit, cbit)
    qc.h(qubit)
    return qc

initial_state = [0,1]
qc = QuantumCircuit(1,1)
qc.initialize(initial_state, 0)
x_measurement(qc,0,0)
qc.draw()
# Out:
#      ┌─────────────────┐┌───┐┌─┐┌───┐
#   q: ┤ Initialize(0,1) ├┤ H ├┤M├┤ H ├
#      └─────────────────┘└───┘└╥┘└───┘
# c: 1/═════════════════════════╩══════
#                               0

# %%
import cirq
import numpy as np
print(cirq.google.Bristlecone)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import cirq
#       2 import numpy as np
#       3 def dummy_npwarn_decorator_factory():
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/cirq/__init__.py:33
#      25 from cirq import (
#      26     # Low level
#      27     _version,
#      28     _doc,
#      29     type_workarounds,
#      30 )
#      32 with _import.delay_import('cirq.protocols'):
# ---> 33     from cirq import (
#      34         # Core
#      35         protocols,
#      36         value,
#      37         linalg,
#      38         qis,
#      39         ops,
#      40         devices,
#      41         study,
#      42     )
#      43 from cirq import (
#      44     # Core
#      45     circuits,
#    (...)
#      57     testing,
#      58 )
#      60 # End dependency order list of sub-modules
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/cirq/ops/__init__.py:27
#      19 from cirq.ops.clifford_gate import CliffordGate, SingleQubitCliffordGate
#      21 from cirq.ops.dense_pauli_string import (
#      22     BaseDensePauliString,
#      23     DensePauliString,
#      24     MutableDensePauliString,
#      25 )
# ---> 27 from cirq.ops.boolean_hamiltonian import BooleanHamiltonianGate
#      29 from cirq.ops.common_channels import (
#      30     amplitude_damp,
#      31     AmplitudeDampingChannel,
#    (...)
#      47     ResetChannel,
#      48 )
#      50 from cirq.ops.common_gates import (
#      51     CNOT,
#      52     CNotPowGate,
#    (...)
#      70     ZPowGate,
#      71 )
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/cirq/ops/boolean_hamiltonian.py:34
#      32 from cirq import value
#      33 from cirq.ops import raw_types
# ---> 34 from cirq.ops.linear_combinations import PauliSum, PauliString
#      37 @value.value_equality
#      38 class BooleanHamiltonianGate(raw_types.Gate):
#      39     r"""A gate that represents evolution due to a Hamiltonian from a set of Boolean functions.
#      40
#      41     This gate constructs a diagonal gate in the computational basis that encodes in its
#    (...)
#      51     $$
#      52     """
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/cirq/ops/linear_combinations.py:36
#      34 from sympy.core.expr import Expr
#      35 from sympy.core.symbol import Symbol
# ---> 36 from scipy.sparse import csr_matrix
#      38 from cirq import linalg, protocols, qis, value
#      39 from cirq._doc import document
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/sparse/__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/sparse/_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/_lib/_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/_lib/_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)
#      38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/numpy/testing/__init__.py:11
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/numpy/testing/_private/utils.py:413
#     409         pprint.pprint(desired, msg)
#     410         raise AssertionError(msg.getvalue())
# --> 413 @np._no_nep50_warning()
#     414 def assert_almost_equal(actual, desired, decimal=7, err_msg='', verbose=True):
#     415     """
#     416     Raises an AssertionError if two items are not equal up to desired
#     417     precision.
#    (...)
#     481
#     482     """
#     483     __tracebackhide__ = True  # Hide traceback for py.test
#
# File ~/Estudo/Quantum Computing/.qml/lib/python3.12/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     409         del w
#     410 del _mac_os_check
#     412 # We usually use madvise hugepages support, but on some old kernels it
#     413 # is slow and thus better avoided.
# --> 414 # Specifically kernel version 4.6 had a bug fix which probably fixed this:
#     415 # https://github.com/torvalds/linux/commit/7cf91a98e607c2f935dbcc177d70011e95b8faff
#     416 import os
#     417 use_hugepage = os.environ.get("NUMPY_MADVISE_HUGEPAGE", None)
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'
